# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
X = np.linspace(0, 1, 10)
plt.plot(X, -np.log(X))
# Out:
# C:\Users\alpha\AppData\Local\Temp\ipykernel_8000\3713734290.py:2: RuntimeWarning: divide by zero encountered in log
#   plt.plot(X, -np.log(X))
